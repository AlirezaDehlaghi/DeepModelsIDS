# %% [markdown]
# # 1) read Dataset

# %%
import importlib

helper_function = importlib.import_module("HelperFucntions")
importlib.reload(helper_function)
from HelperFucntions import *
importlib.reload(helper_function)

preprocessor_module = importlib.import_module("Preprocessor")
importlib.reload(preprocessor_module)
from Preprocessor import *
importlib.reload(preprocessor_module)

# create sequences for variable window sizes
def create_sequences(features, labels, window_size, step_size=1):
    x, y = [], []
    for i in range(0, len(features) - window_size + 1, step_size):
        x.append(features[i:(i + window_size)])
        y.append(labels[i + window_size - 1])
    return np.array(x), np.array(y)



import torch
import pandas as pd
from os import path


Report.green(f'Reading dataset for is_binary=True and is_supervised={False} started ...!')
data = pd.read_csv(path.join('..','..','input','Dataset.csv'))
x_train, x_val, x_test, y_train, y_val, y_test = preprocess_data(data= data, is_binary=True, is_supervised=False)

X_train, X_val, y_val, X_test, y_test =  torch.tensor(x_train, dtype=torch.float32),  torch.tensor(x_val, dtype=torch.float32),  torch.tensor(y_val, dtype=torch.int32), torch.tensor(x_test, dtype=torch.float32),  torch.tensor(y_test, dtype=torch.int32)


if torch.isnan(X_train).any():
    print("❗ Input tensor contains NaN values.")
else:
    print("✅ No NaNs in input tensor.")
# Out:
# [16:24:04] Reading dataset for is_binary=True and is_supervised=False started ...!
# Label Distribution for train:
# 0: 1.000%
# Label Distribution for validation:
# 0: 0.658%
# 1: 0.342%
# Label Distribution for test:
# 0: 0.732%
# 1: 0.268%
# data shape: (45718, 52)
# x_train shape: (17372, 52)
# y_val shape: (19201,)
# y_test shape: (9145,)
# ✅ No NaNs in input tensor.

# %% [markdown]
# # 2) Grid Search

# %%
# def create_sequences(features, labels, window_size, step_size=1):
#     x, y = [], []
#     for i in range(0, features.size(0) - window_size + 1, step_size):
#         x.append(features[i:i + window_size])
#         y.append(labels[i + window_size - 1])
#     return torch.stack(x), torch.tensor(y)
#
#
# window_size = 20
# X_train_seq, y_train_seq = create_sequences(X_train, y_train, window_size)
# X_val_seq, y_val_seq = create_sequences(X_val, y_val, window_size)
# X_test_seq, y_test_seq = create_sequences(X_test, y_test, window_size)

# %%
models_module = importlib.import_module("Models")
importlib.reload(models_module)
from Models import *
importlib.reload(models_module)
#
#
gridsearch_module = importlib.import_module("GridSearch")
importlib.reload(gridsearch_module)
from GridSearch import *
importlib.reload(gridsearch_module)


import json

np.random.seed(0)
device = "cuda" if torch.cuda.is_available() else "cpu"

# Options: AutoEncoder, VariationalAutoEncoder, ConditionalVariationalAutoEncoder, LSTMAutoEncoder
ModelClass = LSTMAutoEncoder  # 👈 change this to the model you want

# ----- Step 3: Define parameter grid -----
if ModelClass.__name__ in ["AutoEncoder", "VariationalAutoEncoder", "ProbabilisticVariationalEncoder"]:
    # param_grid = {
    #     "hidden_layers": [[64,32]],
    #     "latent_dim": [10, 20, 30],
    #     "dropout": [0.0],
    #     "activation": ["relu"],
    #     "batch_size": [32],
    #     "lr": [ 1e-3],
    #     "optimizer": ["adam"],
    #     "epochs": [ 2, 5]
    # }
    param_grid = {
        "hidden_layers": [[64, 32], [128, 64], [64], [32]],
        "latent_dim": [10, 20, 30],
        "dropout": [0.0, 0.1],
        "activation": ["relu", "leaky_relu"],
        "batch_size": [32],
        "lr": [ 1e-3],
        "optimizer": ["adam", "sgd"],
        "epochs": [10]
    }
    input_data = X_train
    cond_data = None
    input_dim = X_train.shape[1]
    test_data_tensor = X_val
    test_labels = y_val
    test_cond_tensor=None




elif ModelClass.__name__ == "ConditionalVariationalAutoEncoder":
    X_tensor = X_train[:, :47]  # normal features
    C_tensor = X_train[:, 47:]  # one-hot protocol features
    param_grid = {
        "hidden_layers": [[64, 32], [128, 64], [64], [32]],
        "latent_dim": [10, 20 , 30],
        "dropout": [0.0, 0.1],
        "activation": ["relu", "leaky_relu"],
        "batch_size": [32],
        "lr": [ 1e-3],
        "optimizer": ["adam", "sgd"],
        "epochs": [50]
    }
    input_data = X_tensor
    cond_data = C_tensor
    input_dim = X_tensor.shape[1]
    test_data_tensor = X_val[:, :47]
    test_labels = y_val
    test_cond_tensor=X_val[:, 47:]



elif ModelClass.__name__ == "LSTMAutoEncoder":
    param_grid = {
        "hidden_dim": [128, 64, 32],
        "latent_dim": [10, 20, 30],
        "num_layers": [1, 2, 3],
        "batch_size": [32],
        "lr": [1e-3],
        "optimizer": ["adam", "sgd"],
        "epochs": [50],
        "window_size": [5, 10, 20],

    }

    # param_grid = {
    #     "hidden_dim": [32],
    #     "latent_dim": [10],
    #     "num_layers": [1, ],
    #     "batch_size": [32],
    #     "lr": [1e-3],
    #     "optimizer": ["adam", "sgd"],
    #     "epochs": [100],
    #     "window_size": [20],
    #
    # }
    input_data = X_train
    cond_data = None
    input_dim = X_train.shape[1]
    test_data_tensor = X_val
    test_labels = y_val
    test_cond_tensor=None
    # input_data = X_train_seq
    # cond_data = None
    # input_dim = X_train_seq.shape[2]
    # test_data_tensor = X_val_seq
    # test_labels = y_val_seq
    # test_cond_tensor=None

else:
    raise ValueError("Unsupported model type")

# ----- Step 4: Run grid search -----
print("\nRunning: ", ModelClass.__name__)
best_config, best_config_by_accuracy, all_results = grid_search_autoencoder(
    data_tensor=input_data,
    param_grid=param_grid,
    input_dim=input_dim,
    model_class=ModelClass,
    device=device,
    cond_tensor=cond_data,
    verbose=True,
    test_data_tensor=test_data_tensor,
    test_labels=test_labels,
    test_cond_tensor=test_cond_tensor,  # optional
    result_path = f"GridSearchResults/cach_{ModelClass.__name__}"
)
print("\n✅ Best configuration:", best_config)
print("\n🎯 Best Config by Test Accuracy:", best_config_by_accuracy)

# Save results
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
model_name = ModelClass.__name__
outfile = f"GridSearchResults/results_{model_name}_{timestamp}.json"

safe_data = convert_to_serializable({
    "model": model_name,
    "search_space":param_grid,
    "best_config": best_config,
    "best_config_by_accuracy": best_config_by_accuracy,
    "all_results": all_results
})

with open(outfile, "w") as f:
    json.dump(safe_data, f, indent=2)

print(f"\n📁 Results saved to {outfile}")
# Out:
# Running:  LSTMAutoEncoder
#
# ⚠️ Skipping already evaluated config 1: {'hidden_dim': 128, 'latent_dim': 10, 'num_layers': 1, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 5}
#
# ⚠️ Skipping already evaluated config 2: {'hidden_dim': 128, 'latent_dim': 10, 'num_layers': 1, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 10}
#
# ⚠️ Skipping already evaluated config 3: {'hidden_dim': 128, 'latent_dim': 10, 'num_layers': 1, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 20}
#
# ⚠️ Skipping already evaluated config 4: {'hidden_dim': 128, 'latent_dim': 10, 'num_layers': 1, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 5}
#
# ⚠️ Skipping already evaluated config 5: {'hidden_dim': 128, 'latent_dim': 10, 'num_layers': 1, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 10}
#
# ⚠️ Skipping already evaluated config 6: {'hidden_dim': 128, 'latent_dim': 10, 'num_layers': 1, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 20}
#
# ⚠️ Skipping already evaluated config 7: {'hidden_dim': 128, 'latent_dim': 10, 'num_layers': 2, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 5}
#
# ⚠️ Skipping already evaluated config 8: {'hidden_dim': 128, 'latent_dim': 10, 'num_layers': 2, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 10}
#
# ⚠️ Skipping already evaluated config 9: {'hidden_dim': 128, 'latent_dim': 10, 'num_layers': 2, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 20}
#
# ⚠️ Skipping already evaluated config 10: {'hidden_dim': 128, 'latent_dim': 10, 'num_layers': 2, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 5}
#
# ⚠️ Skipping already evaluated config 11: {'hidden_dim': 128, 'latent_dim': 10, 'num_layers': 2, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 10}
#
# ⚠️ Skipping already evaluated config 12: {'hidden_dim': 128, 'latent_dim': 10, 'num_layers': 2, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 20}
#
# ⚠️ Skipping already evaluated config 13: {'hidden_dim': 128, 'latent_dim': 10, 'num_layers': 3, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 5}
#
# ⚠️ Skipping already evaluated config 14: {'hidden_dim': 128, 'latent_dim': 10, 'num_layers': 3, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 10}
#
# ⚠️ Skipping already evaluated config 15: {'hidden_dim': 128, 'latent_dim': 10, 'num_layers': 3, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 20}
#
# ⚠️ Skipping already evaluated config 16: {'hidden_dim': 128, 'latent_dim': 10, 'num_layers': 3, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 5}
#
# ⚠️ Skipping already evaluated config 17: {'hidden_dim': 128, 'latent_dim': 10, 'num_layers': 3, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 10}
#
# ⚠️ Skipping already evaluated config 18: {'hidden_dim': 128, 'latent_dim': 10, 'num_layers': 3, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 20}
#
# ⚠️ Skipping already evaluated config 19: {'hidden_dim': 128, 'latent_dim': 20, 'num_layers': 1, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 5}
#
# ⚠️ Skipping already evaluated config 20: {'hidden_dim': 128, 'latent_dim': 20, 'num_layers': 1, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 10}
#
# ⚠️ Skipping already evaluated config 21: {'hidden_dim': 128, 'latent_dim': 20, 'num_layers': 1, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 20}
#
# ⚠️ Skipping already evaluated config 22: {'hidden_dim': 128, 'latent_dim': 20, 'num_layers': 1, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 5}
#
# ⚠️ Skipping already evaluated config 23: {'hidden_dim': 128, 'latent_dim': 20, 'num_layers': 1, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 10}
#
# ⚠️ Skipping already evaluated config 24: {'hidden_dim': 128, 'latent_dim': 20, 'num_layers': 1, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 20}
#
# ⚠️ Skipping already evaluated config 25: {'hidden_dim': 128, 'latent_dim': 20, 'num_layers': 2, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 5}
#
# ⚠️ Skipping already evaluated config 26: {'hidden_dim': 128, 'latent_dim': 20, 'num_layers': 2, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 10}
#
# ⚠️ Skipping already evaluated config 27: {'hidden_dim': 128, 'latent_dim': 20, 'num_layers': 2, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 20}
#
# ⚠️ Skipping already evaluated config 28: {'hidden_dim': 128, 'latent_dim': 20, 'num_layers': 2, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 5}
#
# ⚠️ Skipping already evaluated config 29: {'hidden_dim': 128, 'latent_dim': 20, 'num_layers': 2, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 10}
#
# ⚠️ Skipping already evaluated config 30: {'hidden_dim': 128, 'latent_dim': 20, 'num_layers': 2, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 20}
#
# ⚠️ Skipping already evaluated config 31: {'hidden_dim': 128, 'latent_dim': 20, 'num_layers': 3, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 5}
#
# ⚠️ Skipping already evaluated config 32: {'hidden_dim': 128, 'latent_dim': 20, 'num_layers': 3, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 10}
#
# ⚠️ Skipping already evaluated config 33: {'hidden_dim': 128, 'latent_dim': 20, 'num_layers': 3, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 20}
#
# ⚠️ Skipping already evaluated config 34: {'hidden_dim': 128, 'latent_dim': 20, 'num_layers': 3, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 5}
#
# ⚠️ Skipping already evaluated config 35: {'hidden_dim': 128, 'latent_dim': 20, 'num_layers': 3, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 10}
#
# ⚠️ Skipping already evaluated config 36: {'hidden_dim': 128, 'latent_dim': 20, 'num_layers': 3, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 20}
#
# ⚠️ Skipping already evaluated config 37: {'hidden_dim': 128, 'latent_dim': 30, 'num_layers': 1, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 5}
#
# ⚠️ Skipping already evaluated config 38: {'hidden_dim': 128, 'latent_dim': 30, 'num_layers': 1, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 10}
#
# ⚠️ Skipping already evaluated config 39: {'hidden_dim': 128, 'latent_dim': 30, 'num_layers': 1, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 20}
#
# ⚠️ Skipping already evaluated config 40: {'hidden_dim': 128, 'latent_dim': 30, 'num_layers': 1, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 5}
#
# ⚠️ Skipping already evaluated config 41: {'hidden_dim': 128, 'latent_dim': 30, 'num_layers': 1, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 10}
#
# ⚠️ Skipping already evaluated config 42: {'hidden_dim': 128, 'latent_dim': 30, 'num_layers': 1, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 20}
#
# ⚠️ Skipping already evaluated config 43: {'hidden_dim': 128, 'latent_dim': 30, 'num_layers': 2, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 5}
#
# ⚠️ Skipping already evaluated config 44: {'hidden_dim': 128, 'latent_dim': 30, 'num_layers': 2, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 10}
#
# ⚠️ Skipping already evaluated config 45: {'hidden_dim': 128, 'latent_dim': 30, 'num_layers': 2, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 20}
#
# ⚠️ Skipping already evaluated config 46: {'hidden_dim': 128, 'latent_dim': 30, 'num_layers': 2, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 5}
#
# ⚠️ Skipping already evaluated config 47: {'hidden_dim': 128, 'latent_dim': 30, 'num_layers': 2, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 10}
#
# ⚠️ Skipping already evaluated config 48: {'hidden_dim': 128, 'latent_dim': 30, 'num_layers': 2, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 20}
#
# ⚠️ Skipping already evaluated config 49: {'hidden_dim': 128, 'latent_dim': 30, 'num_layers': 3, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 5}
#
# ⚠️ Skipping already evaluated config 50: {'hidden_dim': 128, 'latent_dim': 30, 'num_layers': 3, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 10}
#
# ⚠️ Skipping already evaluated config 51: {'hidden_dim': 128, 'latent_dim': 30, 'num_layers': 3, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 20}
#
# ⚠️ Skipping already evaluated config 52: {'hidden_dim': 128, 'latent_dim': 30, 'num_layers': 3, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 5}
#
# ⚠️ Skipping already evaluated config 53: {'hidden_dim': 128, 'latent_dim': 30, 'num_layers': 3, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 10}
#
# ⚠️ Skipping already evaluated config 54: {'hidden_dim': 128, 'latent_dim': 30, 'num_layers': 3, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 20}
#
# ⚠️ Skipping already evaluated config 55: {'hidden_dim': 64, 'latent_dim': 10, 'num_layers': 1, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 5}
#
# ⚠️ Skipping already evaluated config 56: {'hidden_dim': 64, 'latent_dim': 10, 'num_layers': 1, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 10}
#
# ⚠️ Skipping already evaluated config 57: {'hidden_dim': 64, 'latent_dim': 10, 'num_layers': 1, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 20}
#
# ⚠️ Skipping already evaluated config 58: {'hidden_dim': 64, 'latent_dim': 10, 'num_layers': 1, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 5}
#
# ⚠️ Skipping already evaluated config 59: {'hidden_dim': 64, 'latent_dim': 10, 'num_layers': 1, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 10}
#
# ⚠️ Skipping already evaluated config 60: {'hidden_dim': 64, 'latent_dim': 10, 'num_layers': 1, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 20}
#
# ⚠️ Skipping already evaluated config 61: {'hidden_dim': 64, 'latent_dim': 10, 'num_layers': 2, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 5}
#
# ⚠️ Skipping already evaluated config 62: {'hidden_dim': 64, 'latent_dim': 10, 'num_layers': 2, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 10}
#
# ⚠️ Skipping already evaluated config 63: {'hidden_dim': 64, 'latent_dim': 10, 'num_layers': 2, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 20}
#
# ⚠️ Skipping already evaluated config 64: {'hidden_dim': 64, 'latent_dim': 10, 'num_layers': 2, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 5}
#
# ⚠️ Skipping already evaluated config 65: {'hidden_dim': 64, 'latent_dim': 10, 'num_layers': 2, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 10}
#
# ⚠️ Skipping already evaluated config 66: {'hidden_dim': 64, 'latent_dim': 10, 'num_layers': 2, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 20}
#
# ⚠️ Skipping already evaluated config 67: {'hidden_dim': 64, 'latent_dim': 10, 'num_layers': 3, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 5}
#
# ⚠️ Skipping already evaluated config 68: {'hidden_dim': 64, 'latent_dim': 10, 'num_layers': 3, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 10}
#
# ⚠️ Skipping already evaluated config 69: {'hidden_dim': 64, 'latent_dim': 10, 'num_layers': 3, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 20}
#
# ⚠️ Skipping already evaluated config 70: {'hidden_dim': 64, 'latent_dim': 10, 'num_layers': 3, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 5}
#
# ⚠️ Skipping already evaluated config 71: {'hidden_dim': 64, 'latent_dim': 10, 'num_layers': 3, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 10}
#
# ⚠️ Skipping already evaluated config 72: {'hidden_dim': 64, 'latent_dim': 10, 'num_layers': 3, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 20}
#
# ⚠️ Skipping already evaluated config 73: {'hidden_dim': 64, 'latent_dim': 20, 'num_layers': 1, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 5}
#
# ⚠️ Skipping already evaluated config 74: {'hidden_dim': 64, 'latent_dim': 20, 'num_layers': 1, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 10}
#
# ⚠️ Skipping already evaluated config 75: {'hidden_dim': 64, 'latent_dim': 20, 'num_layers': 1, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 20}
#
# ⚠️ Skipping already evaluated config 76: {'hidden_dim': 64, 'latent_dim': 20, 'num_layers': 1, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 5}
#
# ⚠️ Skipping already evaluated config 77: {'hidden_dim': 64, 'latent_dim': 20, 'num_layers': 1, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 10}
#
# ⚠️ Skipping already evaluated config 78: {'hidden_dim': 64, 'latent_dim': 20, 'num_layers': 1, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 20}
#
# ⚠️ Skipping already evaluated config 79: {'hidden_dim': 64, 'latent_dim': 20, 'num_layers': 2, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 5}
#
# ⚠️ Skipping already evaluated config 80: {'hidden_dim': 64, 'latent_dim': 20, 'num_layers': 2, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 10}
#
# ⚠️ Skipping already evaluated config 81: {'hidden_dim': 64, 'latent_dim': 20, 'num_layers': 2, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 20}
#
# ⚠️ Skipping already evaluated config 82: {'hidden_dim': 64, 'latent_dim': 20, 'num_layers': 2, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 5}
#
# ⚠️ Skipping already evaluated config 83: {'hidden_dim': 64, 'latent_dim': 20, 'num_layers': 2, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 10}
#
# ⚠️ Skipping already evaluated config 84: {'hidden_dim': 64, 'latent_dim': 20, 'num_layers': 2, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 20}
#
# ⚠️ Skipping already evaluated config 85: {'hidden_dim': 64, 'latent_dim': 20, 'num_layers': 3, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 5}
#
# ⚠️ Skipping already evaluated config 86: {'hidden_dim': 64, 'latent_dim': 20, 'num_layers': 3, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 10}
#
# ⚠️ Skipping already evaluated config 87: {'hidden_dim': 64, 'latent_dim': 20, 'num_layers': 3, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 20}
#
# ⚠️ Skipping already evaluated config 88: {'hidden_dim': 64, 'latent_dim': 20, 'num_layers': 3, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 5}
#
# ⚠️ Skipping already evaluated config 89: {'hidden_dim': 64, 'latent_dim': 20, 'num_layers': 3, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 10}
#
# ⚠️ Skipping already evaluated config 90: {'hidden_dim': 64, 'latent_dim': 20, 'num_layers': 3, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 20}
#
# ⚠️ Skipping already evaluated config 91: {'hidden_dim': 64, 'latent_dim': 30, 'num_layers': 1, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 5}
#
# ⚠️ Skipping already evaluated config 92: {'hidden_dim': 64, 'latent_dim': 30, 'num_layers': 1, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 10}
#
# ⚠️ Skipping already evaluated config 93: {'hidden_dim': 64, 'latent_dim': 30, 'num_layers': 1, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 20}
#
# ⚠️ Skipping already evaluated config 94: {'hidden_dim': 64, 'latent_dim': 30, 'num_layers': 1, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 5}
#
# ⚠️ Skipping already evaluated config 95: {'hidden_dim': 64, 'latent_dim': 30, 'num_layers': 1, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 10}
#
# ⚠️ Skipping already evaluated config 96: {'hidden_dim': 64, 'latent_dim': 30, 'num_layers': 1, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 20}
#
# ⚠️ Skipping already evaluated config 97: {'hidden_dim': 64, 'latent_dim': 30, 'num_layers': 2, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 5}
#
# ⚠️ Skipping already evaluated config 98: {'hidden_dim': 64, 'latent_dim': 30, 'num_layers': 2, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 10}
#
# ⚠️ Skipping already evaluated config 99: {'hidden_dim': 64, 'latent_dim': 30, 'num_layers': 2, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 20}
#
# ⚠️ Skipping already evaluated config 100: {'hidden_dim': 64, 'latent_dim': 30, 'num_layers': 2, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 5}
#
# ⚠️ Skipping already evaluated config 101: {'hidden_dim': 64, 'latent_dim': 30, 'num_layers': 2, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 10}
#
# ⚠️ Skipping already evaluated config 102: {'hidden_dim': 64, 'latent_dim': 30, 'num_layers': 2, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 20}
#
# ⚠️ Skipping already evaluated config 103: {'hidden_dim': 64, 'latent_dim': 30, 'num_layers': 3, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 5}
#
# ⚠️ Skipping already evaluated config 104: {'hidden_dim': 64, 'latent_dim': 30, 'num_layers': 3, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 10}
#
# ⚠️ Skipping already evaluated config 105: {'hidden_dim': 64, 'latent_dim': 30, 'num_layers': 3, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 20}
#
# ⚠️ Skipping already evaluated config 106: {'hidden_dim': 64, 'latent_dim': 30, 'num_layers': 3, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 5}
#
# ⚠️ Skipping already evaluated config 107: {'hidden_dim': 64, 'latent_dim': 30, 'num_layers': 3, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 10}
#
# ⚠️ Skipping already evaluated config 108: {'hidden_dim': 64, 'latent_dim': 30, 'num_layers': 3, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 20}
#
# ⚠️ Skipping already evaluated config 109: {'hidden_dim': 32, 'latent_dim': 10, 'num_layers': 1, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 5}
#
# ⚠️ Skipping already evaluated config 110: {'hidden_dim': 32, 'latent_dim': 10, 'num_layers': 1, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 10}
#
# ⚠️ Skipping already evaluated config 111: {'hidden_dim': 32, 'latent_dim': 10, 'num_layers': 1, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 20}
#
# ⚠️ Skipping already evaluated config 112: {'hidden_dim': 32, 'latent_dim': 10, 'num_layers': 1, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 5}
#
# ⚠️ Skipping already evaluated config 113: {'hidden_dim': 32, 'latent_dim': 10, 'num_layers': 1, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 10}
#
# ⚠️ Skipping already evaluated config 114: {'hidden_dim': 32, 'latent_dim': 10, 'num_layers': 1, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 20}
#
# ⚠️ Skipping already evaluated config 115: {'hidden_dim': 32, 'latent_dim': 10, 'num_layers': 2, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 5}
#
# ⚠️ Skipping already evaluated config 116: {'hidden_dim': 32, 'latent_dim': 10, 'num_layers': 2, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 10}
#
# ⚠️ Skipping already evaluated config 117: {'hidden_dim': 32, 'latent_dim': 10, 'num_layers': 2, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 20}
#
# ⚠️ Skipping already evaluated config 118: {'hidden_dim': 32, 'latent_dim': 10, 'num_layers': 2, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 5}
#
# ⚠️ Skipping already evaluated config 119: {'hidden_dim': 32, 'latent_dim': 10, 'num_layers': 2, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 10}
#
# ⚠️ Skipping already evaluated config 120: {'hidden_dim': 32, 'latent_dim': 10, 'num_layers': 2, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 20}
#
# ⚠️ Skipping already evaluated config 121: {'hidden_dim': 32, 'latent_dim': 10, 'num_layers': 3, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 5}
#
# ⚠️ Skipping already evaluated config 122: {'hidden_dim': 32, 'latent_dim': 10, 'num_layers': 3, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 10}
#
# ⚠️ Skipping already evaluated config 123: {'hidden_dim': 32, 'latent_dim': 10, 'num_layers': 3, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 20}
#
# ⚠️ Skipping already evaluated config 124: {'hidden_dim': 32, 'latent_dim': 10, 'num_layers': 3, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 5}
#
# ⚠️ Skipping already evaluated config 125: {'hidden_dim': 32, 'latent_dim': 10, 'num_layers': 3, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 10}
#
# ⚠️ Skipping already evaluated config 126: {'hidden_dim': 32, 'latent_dim': 10, 'num_layers': 3, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 20}
#
# ⚠️ Skipping already evaluated config 127: {'hidden_dim': 32, 'latent_dim': 20, 'num_layers': 1, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 5}
#
# ⚠️ Skipping already evaluated config 128: {'hidden_dim': 32, 'latent_dim': 20, 'num_layers': 1, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 10}
#
# ⚠️ Skipping already evaluated config 129: {'hidden_dim': 32, 'latent_dim': 20, 'num_layers': 1, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 20}
#
# ⚠️ Skipping already evaluated config 130: {'hidden_dim': 32, 'latent_dim': 20, 'num_layers': 1, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 5}
#
# ⚠️ Skipping already evaluated config 131: {'hidden_dim': 32, 'latent_dim': 20, 'num_layers': 1, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 10}
#
# ⚠️ Skipping already evaluated config 132: {'hidden_dim': 32, 'latent_dim': 20, 'num_layers': 1, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 20}
#
# ⚠️ Skipping already evaluated config 133: {'hidden_dim': 32, 'latent_dim': 20, 'num_layers': 2, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 5}
#
# ⚠️ Skipping already evaluated config 134: {'hidden_dim': 32, 'latent_dim': 20, 'num_layers': 2, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 10}
#
# ⚠️ Skipping already evaluated config 135: {'hidden_dim': 32, 'latent_dim': 20, 'num_layers': 2, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 20}
#
# ⚠️ Skipping already evaluated config 136: {'hidden_dim': 32, 'latent_dim': 20, 'num_layers': 2, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 5}
#
# ⚠️ Skipping already evaluated config 137: {'hidden_dim': 32, 'latent_dim': 20, 'num_layers': 2, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 10}
#
# ⚠️ Skipping already evaluated config 138: {'hidden_dim': 32, 'latent_dim': 20, 'num_layers': 2, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 20}
#
# ⚠️ Skipping already evaluated config 139: {'hidden_dim': 32, 'latent_dim': 20, 'num_layers': 3, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 5}
#
# ⚠️ Skipping already evaluated config 140: {'hidden_dim': 32, 'latent_dim': 20, 'num_layers': 3, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 10}
#
# ⚠️ Skipping already evaluated config 141: {'hidden_dim': 32, 'latent_dim': 20, 'num_layers': 3, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 20}
#
# ⚠️ Skipping already evaluated config 142: {'hidden_dim': 32, 'latent_dim': 20, 'num_layers': 3, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 5}
#
# ⚠️ Skipping already evaluated config 143: {'hidden_dim': 32, 'latent_dim': 20, 'num_layers': 3, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 10}
#
# ⚠️ Skipping already evaluated config 144: {'hidden_dim': 32, 'latent_dim': 20, 'num_layers': 3, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 20}
#
# ⚠️ Skipping already evaluated config 145: {'hidden_dim': 32, 'latent_dim': 30, 'num_layers': 1, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 5}
#
# ⚠️ Skipping already evaluated config 146: {'hidden_dim': 32, 'latent_dim': 30, 'num_layers': 1, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 10}
#
# ⚠️ Skipping already evaluated config 147: {'hidden_dim': 32, 'latent_dim': 30, 'num_layers': 1, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 20}
#
# ⚠️ Skipping already evaluated config 148: {'hidden_dim': 32, 'latent_dim': 30, 'num_layers': 1, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 5}
#
# ⚠️ Skipping already evaluated config 149: {'hidden_dim': 32, 'latent_dim': 30, 'num_layers': 1, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 10}
#
# ⚠️ Skipping already evaluated config 150: {'hidden_dim': 32, 'latent_dim': 30, 'num_layers': 1, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 20}
#
# ⚠️ Skipping already evaluated config 151: {'hidden_dim': 32, 'latent_dim': 30, 'num_layers': 2, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 5}
#
# ⚠️ Skipping already evaluated config 152: {'hidden_dim': 32, 'latent_dim': 30, 'num_layers': 2, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 10}
#
# 🔍 Trying config 153: {'hidden_dim': 32, 'latent_dim': 30, 'num_layers': 2, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 20}
# Epoch [1/50], Loss: 0.039119
# Epoch [2/50], Loss: 0.021761
# Epoch [3/50], Loss: 0.021763
# Epoch [4/50], Loss: 0.021764
# Epoch [5/50], Loss: 0.021765
# Epoch [6/50], Loss: 0.021768
# Epoch [7/50], Loss: 0.021769
# Epoch [8/50], Loss: 0.021767
# Epoch [9/50], Loss: 0.021769
# Epoch [10/50], Loss: 0.021768
# Epoch [11/50], Loss: 0.021768
# Epoch [12/50], Loss: 0.021767
# Epoch [13/50], Loss: 0.021555
# Epoch [14/50], Loss: 0.020847
# Epoch [15/50], Loss: 0.020066
# Epoch [16/50], Loss: 0.019422
# Epoch [17/50], Loss: 0.018963
# Epoch [18/50], Loss: 0.019089
# Epoch [19/50], Loss: 0.018657
# Epoch [20/50], Loss: 0.018551
# Epoch [21/50], Loss: 0.018427
# Epoch [22/50], Loss: 0.020889
# Epoch [23/50], Loss: 0.020780
# Epoch [24/50], Loss: 0.020513
# Epoch [25/50], Loss: 0.020091
# Epoch [26/50], Loss: 0.019880
# Epoch [27/50], Loss: 0.019685
# Epoch [28/50], Loss: 0.019581
# Epoch [29/50], Loss: 0.019256
# Epoch [30/50], Loss: 0.019034
# Epoch [31/50], Loss: 0.018914
# Epoch [32/50], Loss: 0.018699
# Epoch [33/50], Loss: 0.018595
# Epoch [34/50], Loss: 0.018498
# Epoch [35/50], Loss: 0.018393
# Epoch [36/50], Loss: 0.018225
# Epoch [43/50], Loss: 0.063938
# Epoch [44/50], Loss: 0.061652
# Epoch [45/50], Loss: 0.059467
# Epoch [46/50], Loss: 0.057411
# Epoch [47/50], Loss: 0.055449
# Epoch [48/50], Loss: 0.053581
# Epoch [49/50], Loss: 0.051816
# Epoch [50/50], Loss: 0.050141
# 📈 Threshold: 0.0624 | Accuracy: 0.9189 | Precision: 0.9615 | Recall: 0.7945 | F1: 0.8701
# ✅ Validation MSE: 0.042067
#
# 🔍 Trying config 161: {'hidden_dim': 32, 'latent_dim': 30, 'num_layers': 3, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 10}
# Epoch [1/50], Loss: 0.282963
# Epoch [2/50], Loss: 0.272284
# Epoch [3/50], Loss: 0.262088
# Epoch [4/50], Loss: 0.252340
# Epoch [5/50], Loss: 0.242995
# Epoch [6/50], Loss: 0.234012
# Epoch [7/50], Loss: 0.225402
# Epoch [8/50], Loss: 0.217097
# Epoch [9/50], Loss: 0.209096
# Epoch [10/50], Loss: 0.201393
# Epoch [11/50], Loss: 0.194002
# Epoch [12/50], Loss: 0.186840
# Epoch [13/50], Loss: 0.179926
# Epoch [14/50], Loss: 0.173286
# Epoch [15/50], Loss: 0.166823
# Epoch [16/50], Loss: 0.160648
# Epoch [17/50], Loss: 0.154619
# Epoch [18/50], Loss: 0.148869
# Epoch [19/50], Loss: 0.143269
# Epoch [20/50], Loss: 0.137886
# Epoch [21/50], Loss: 0.132656
# Epoch [22/50], Loss: 0.127648
# Epoch [23/50], Loss: 0.122791
# Epoch [24/50], Loss: 0.118108
# Epoch [25/50], Loss: 0.113597
# Epoch [26/50], Loss: 0.109243
# Epoch [27/50], Loss: 0.105074
# Epoch [28/50], Loss: 0.101056
# Epoch [29/50], Loss: 0.097168
# Epoch [30/50], Loss: 0.093441
# Epoch [31/50], Loss: 0.089869
# Epoch [32/50], Loss: 0.086427
# Epoch [33/50], Loss: 0.083120
# Epoch [34/50], Loss: 0.079965
# Epoch [35/50], Loss: 0.076942
# Epoch [36/50], Loss: 0.074037
# Epoch [37/50], Loss: 0.071260
# Epoch [38/50], Loss: 0.068609
# Epoch [39/50], Loss: 0.066066
# Epoch [40/50], Loss: 0.063649
# Epoch [41/50], Loss: 0.061350
# Epoch [42/50], Loss: 0.059144
# Epoch [43/50], Loss: 0.057072
# Epoch [44/50], Loss: 0.055066
# Epoch [45/50], Loss: 0.053176
# Epoch [46/50], Loss: 0.051383
# Epoch [47/50], Loss: 0.049668
# Epoch [48/50], Loss: 0.048064
# Epoch [49/50], Loss: 0.046539
# Epoch [50/50], Loss: 0.045094
# 📈 Threshold: 0.0583 | Accuracy: 0.9187 | Precision: 0.9599 | Recall: 0.7955 | F1: 0.8700
# ✅ Validation MSE: 0.040519
#
# 🔍 Trying config 162: {'hidden_dim': 32, 'latent_dim': 30, 'num_layers': 3, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'sgd', 'epochs': 50, 'window_size': 20}
# Epoch [1/50], Loss: 0.291763
# Epoch [2/50], Loss: 0.279857
# Epoch [3/50], Loss: 0.268454
# Epoch [4/50], Loss: 0.257509
# Epoch [5/50], Loss: 0.246982
# Epoch [6/50], Loss: 0.236837
# Epoch [7/50], Loss: 0.227049
# Epoch [8/50], Loss: 0.217590
# Epoch [9/50], Loss: 0.208442
# Epoch [10/50], Loss: 0.199587
# Epoch [11/50], Loss: 0.191010
# Epoch [12/50], Loss: 0.182699
# Epoch [13/50], Loss: 0.174645
# Epoch [14/50], Loss: 0.166840
# Epoch [15/50], Loss: 0.159277
# Epoch [16/50], Loss: 0.151952
# Epoch [17/50], Loss: 0.144862
# Epoch [18/50], Loss: 0.138006
# Epoch [19/50], Loss: 0.131381
# Epoch [20/50], Loss: 0.124987
# Epoch [21/50], Loss: 0.118826
# Epoch [22/50], Loss: 0.112897
# Epoch [23/50], Loss: 0.107200
# Epoch [24/50], Loss: 0.101738
# Epoch [25/50], Loss: 0.096509
# Epoch [26/50], Loss: 0.091515
# Epoch [27/50], Loss: 0.086755
# Epoch [28/50], Loss: 0.082228
# Epoch [29/50], Loss: 0.077934
# Epoch [30/50], Loss: 0.073868
# Epoch [31/50], Loss: 0.070030
# Epoch [32/50], Loss: 0.066414
# Epoch [33/50], Loss: 0.063017
# Epoch [34/50], Loss: 0.059832
# Epoch [35/50], Loss: 0.056855
# Epoch [36/50], Loss: 0.054078
# Epoch [37/50], Loss: 0.051494
# Epoch [38/50], Loss: 0.049096
# Epoch [39/50], Loss: 0.046875
# Epoch [40/50], Loss: 0.044823
# Epoch [41/50], Loss: 0.042931
# Epoch [42/50], Loss: 0.041191
# Epoch [43/50], Loss: 0.039593
# Epoch [44/50], Loss: 0.038129
# Epoch [45/50], Loss: 0.036790
# Epoch [46/50], Loss: 0.035568
# Epoch [47/50], Loss: 0.034454
# Epoch [48/50], Loss: 0.033440
# Epoch [49/50], Loss: 0.032519
# Epoch [50/50], Loss: 0.031683
# 📈 Threshold: 0.0507 | Accuracy: 0.9148 | Precision: 0.9554 | Recall: 0.7875 | F1: 0.8634
# ✅ Validation MSE: 0.027636
#
# 🏆 Best Config: {'hidden_dim': 128, 'latent_dim': 30, 'num_layers': 1, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 5}
# Lowest Validation MSE: 0.000156
#
# 🎯 Best Config by Test Accuracy: {'hidden_dim': 64, 'latent_dim': 10, 'num_layers': 2, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 5}
# Highest Test Accuracy: 0.9528
#
# ✅ Best configuration: {'hidden_dim': 128, 'latent_dim': 30, 'num_layers': 1, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 5}
#
# 🎯 Best Config by Test Accuracy: {'hidden_dim': 64, 'latent_dim': 10, 'num_layers': 2, 'batch_size': 32, 'lr': 0.001, 'optimizer': 'adam', 'epochs': 50, 'window_size': 5}
#
# 📁 Results saved to GridSearchResults/results_LSTMAutoEncoder_20250514_200730.json

# %% [markdown]
# # Final Data

# %%
# 4. Train final model on full data
final_dataset = TensorDataset(X_train)
final_model = AutoEncoder(
    input_dim=52,
    encoder_layers=best_config["encoder_layers"],
    decoder_layers=best_config["decoder_layers"],
    dropout=best_config["dropout"],
    activation=best_config["activation"]
)

train_autoencoder(
    final_model,
    train_data=final_dataset,
    batch_size=best_config["batch_size"],
    lr=best_config["lr"],
    optimizer_name=best_config["optimizer"],
    num_epochs=best_config["epochs"],
    device="cpu"
)

# 5. Compute anomaly scores
reconstruction_errors = compute_reconstruction_error(final_model, data_tensor)
threshold = np.percentile(reconstruction_errors, 95)
anomalies = reconstruction_errors > threshold

print("\n📊 Total anomalies detected:", np.sum(anomalies))
